# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

data = pd.read_csv("healthcare-dataset-stroke-data.csv")
print(data)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
#Total Records:

len(data)
# Out:
# 5110

# %%
# Mean, Median, SD on various numerical columns:

data.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
#Total null values in different columns:

data.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
# Visualizing the data

import matplotlib.pyplot as plt
plt.hist(df['age'], bins=range(0,80,5), edgecolor='black')
plt.xlabel('Age of Patients')
plt.ylabel('No. of Patients')
# Out:
# Text(0, 0.5, 'No. of Patients')

# %% [markdown]
# So, this is the histogram of age of patients from which we can clearly see that most of the patients reside into the age group of 40 to 60. Frequency of patients having age less than 40 is less.

# %%
# library & dataset
import seaborn as sns
sns.set(style="darkgrid")

# Make default density plot
fig = sns.kdeplot(df['bmi'], shade=True, color="r")
fig = sns.kdeplot(df['age'], shade=True, color="b")
plt.show()

# %% [markdown]
# Here RED indicates BMI of patients and BLUE represents AGE of patients. We can compare those two attributes in one frame.

# %%
# Comparing AGE and Glucose level
sns.scatterplot(data=data, x="age", y="avg_glucose_level")
# Out:
# <AxesSubplot:xlabel='age', ylabel='avg_glucose_level'>

# %% [markdown]
# From this plot we can conclude that average glucose level of patients having age greater than 40 are more dense that means they have high average sugar level as compared to others.
